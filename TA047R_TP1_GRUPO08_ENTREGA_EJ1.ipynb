# %% [markdown]
# <a href="https://colab.research.google.com/github/maximogiovanettoni/Paradigmas_de_la_Programacion/blob/main/TA047R_TP1_GRUPO08_ENTREGA_EJ1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pyarrow.parquet as pq

# Descargamos datasets
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-04.parquet -O yellow_tripdata_2024-04.parquet
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-05.parquet -O yellow_tripdata_2024-05.parquet
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-06.parquet -O yellow_tripdata_2024-06.parquet
# !gdown 121-MQOXDQI1uTDXgiDETE4VSId1qnYSB
# Leemos cada archivo
trips4 = pq.read_table('/content/yellow_tripdata_2024-04.parquet')
dataAbril = trips4.to_pandas()

trips5 = pq.read_table('/content/yellow_tripdata_2024-05.parquet')
dataMayo = trips5.to_pandas()

trips6 = pq.read_table('/content/yellow_tripdata_2024-06.parquet')
dataJunio = trips6.to_pandas()

# Unimos en un solo DataFrame
data_AMJ = pd.concat([dataAbril, dataMayo, dataJunio], axis=0, ignore_index=True)

# Cargamos zonas (el mismo CSV de antes)
stations = pd.read_csv('/content/taxi_zone_lookup.csv')

# Verificamos
print(data_AMJ.shape)
data_AMJ.head()
# Out:
# --2025-09-02 13:47:48--  https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-04.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 108.138.245.225, 108.138.245.16, 108.138.245.96, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|108.138.245.225|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59133625 (56M) [binary/octet-stream]
# Saving to: ‘yellow_tripdata_2024-04.parquet’
#
# yellow_tripdata_202 100%[===================>]  56.39M   146MB/s    in 0.4s
#
# 2025-09-02 13:47:49 (146 MB/s) - ‘yellow_tripdata_2024-04.parquet’ saved [59133625/59133625]
#
# --2025-09-02 13:47:49--  https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-05.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 108.138.245.225, 108.138.245.16, 108.138.245.96, ...
# ...
